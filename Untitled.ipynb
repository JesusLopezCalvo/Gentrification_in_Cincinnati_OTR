# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing pickle files

pdf1950 = pd.read_pickle('Notebooks and pkls/pdf1950.pkl')
pdf1960 = pd.read_pickle('Notebooks and pkls/pdf1960.pkl')
pdf1970 = pd.read_pickle('Notebooks and pkls/pdf1970.pkl')
pdf1980 = pd.read_pickle('Notebooks and pkls/pdf1980.pkl')
pdf1990 = pd.read_pickle('Notebooks and pkls/pdf1990.pkl')
pdf2000 = pd.read_pickle('Notebooks and pkls/pdf2000.pkl')
pdf2010 = pd.read_pickle('Notebooks and pkls/pdf2010.pkl')
pdf2020 = pd.read_pickle('Notebooks and pkls/pdf2020.pkl')

df_edu_2000 = pd.read_pickle('Notebooks and pkls/df_edu_2000.pkl')
df_edu_2010 = pd.read_pickle('Notebooks and pkls/df_edu_2010.pkl')
df_edu_2020 = pd.read_pickle('Notebooks and pkls/df_edu_2020.pkl')

df_inc_2000 = pd.read_pickle('Notebooks and pkls/df_inc_2000.pkl')
df_inc_2010 = pd.read_pickle('Notebooks and pkls/df_inc_2010.pkl')
df_inc_2020 = pd.read_pickle('Notebooks and pkls/df_inc_2020.pkl')

# %%
for i, row in pdf1950.iloc[1:2].iterrows():
    White_1950_list.append([row['Census Tract 9, Hamilton County, Ohio'], row['Census Tract 10, Hamilton County, Ohio'],
                       row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
                       row['TOTAL (All Selected Census Tracts)']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
#       1 for i, row in pdf1950.iloc[1:2].iterrows():
# ----> 2     White_1950_list.append([row['Census Tract 9, Hamilton County, Ohio'], row['Census Tract 10, Hamilton County, Ohio'],
#       3                        row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
#       4                        row['TOTAL (All Selected Census Tracts)']])
#
# NameError: name 'White_1950_list' is not defined

# %%
wdf2 = pd.DataFrame(White_list)

# %%
White_1950_list =[]
White_list = [pdf1950.iloc[[1]:2],pdf1960.iloc[[1]:2],pdf1970.iloc[[1]:2],pdf1980.iloc[[1]:2],
              pdf1990.iloc[[1]:2],pdf2000.iloc[[1]:2], pdf2010.iloc[[1]:2], pdf2020.iloc[[1]:2]]

for i,row in White_list.iterrows():
    White_1950_list.append([row['Census Tract 9, Hamilton County, Ohio'],row['Census Tract 10, Hamilton County, Ohio'],
                       row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
                       row['TOTAL (All Selected Census Tracts)']])
White_1950_list

# %%
Wdata = {}
for name in White_list:
    Wdata[name] = pd.DataFrame()

# %%
White_1950_list =[]
White_list = [pdf1950.iloc[1:2],pdf1960.iloc[1:2],pdf1970.iloc[1:2],pdf1980.iloc[1:2],
              pdf1990.iloc[1:2],pdf2000.iloc[1:2], pdf2010.iloc[1:2], pdf2020.iloc[1:2]]

wls = pd.DataFrame(White_list)
#for i in White_list():
    #White_1950_list.append([i, i+1])

# %%
i = pdf1950
White_list = []
for i in White_list:
    for i, row in pdf1950.iloc[1:2].iterrows():
        White_1950_list.append([row['Census Tract 9, Hamilton County, Ohio'], row['Census Tract 10, Hamilton County, Ohio'],
        row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
        row['TOTAL (All Selected Census Tracts)']])
        i = i+10
    if i == 2010:
        break
        
        #mynew =[row['Census Tract 9, Hamilton County, Ohio'], row['Census Tract 10, Hamilton County, Ohio'],
                       #row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
                       #row['TOTAL (All Selected Census Tracts)']]

# %%
White_1960_list

# %%
#It works for the first dataframe 1950

datakeyArray = ['Census Tract 9, Hamilton County, Ohio', 'Census Tract 10, Hamilton County, Ohio',
                'Census Tract 16, Hamilton County, Ohio', 'Census Tract 17, Hamilton County, Ohio',
                'TOTAL (All Selected Census Tracts)']

def CreateNewDf(dataFrame):
    mynew = None
    dataframe = [pdf1950, pdf1960,pdf1970, pdf1980,pdf1990,pdf2000,pdf2010,pdf2020]
    dataframe = pd.concat(dataframe)
    for i in dataframe:
        mynew = []
        #return dataframe
    for i, row in dataframe.iloc[1:2].iterrows():
        mynew = [row[datakeyArray[0]], row[datakeyArray[1]], row[datakeyArray[2]], 
                 row[datakeyArray[3]], row[datakeyArray[4]]]
    return mynew

# %%
datakeyArray = ['Census Tract 9, Hamilton County, Ohio', 'Census Tract 10, Hamilton County, Ohio',
                'Census Tract 16, Hamilton County, Ohio', 'Census Tract 17, Hamilton County, Ohio',
                'TOTAL (All Selected Census Tracts)']

def CreateNewDf(dataFrame):
    #mynew = None
    newFrame = []
    dataframe = [pdf1950, pdf1960,pdf1970, pdf1980,pdf1990,pdf2000,pdf2010,pdf2020]
    dataframe = pd.concat(dataframe)
    for i in dataframe:
        newFrame = []
        #return dataframe
    for row in dataframe.iterrows():
        newFrame.append([[row[datakeyArray[0]]], [row[datakeyArray[1]]], [row[datakeyArray[2]]], 
                 [row[datakeyArray[3]]], [row[datakeyArray[4]]]])
        pd.concat(newFrame)
    return newFrame

# %%
#Chris code
newFrame = []
for row in dataframe.iterrows():[row.iloc[1:2]
  newFrame.append([row.iloc[1:2][datakeyArray[0]], ...])
pd.concat(newFrame)

# %%
    for row in dataframe.iterrows():
        newFrame.append([row.iloc[1:2][datakeyArray[0]]], [row.iloc[1:2][datakeyArray[1]]], [row.iloc[1:2][datakeyArray[2]]], 
                 [row.iloc[1:2][datakeyArray[3]]], [row.iloc[1:2][datakeyArray[4]]])
    return newFrame

# %%
CreateNewDf(pdf1960)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [121], in <cell line: 1>()
# ----> 1 CreateNewDf(pdf1960)
#
# Input In [120], in CreateNewDf(dataFrame)
#      12     #return dataframe
#      13 for row in dataframe.iterrows():
# ---> 14     newFrame.append([[row[datakeyArray[0]]], [row[datakeyArray[1]]], [row[datakeyArray[2]]],
#      15              [row[datakeyArray[3]]], [row[datakeyArray[4]]]])
#      16     pd.concat(newFrame)
#      17 return newFrame
#
# TypeError: tuple indices must be integers or slices, not str

# %%
dataframe = [pdf1950, pdf1960,pdf1970, pdf1980,pdf1990,pdf2000,pdf2010,pdf2020]
dataframe = pd.concat(dataframe)
def f(dataframe):
    for i in dataframe:
        return dataframe

# %%
f(pdf1950)
# Out:
#              Category  Census Tract 9, Hamilton County, Ohio  \
# 13  Total Population:                                 7565.0
# 14              White                                 7474.0
# 15              Black                                   79.0
# 16              Other                                   12.0
#
#     Census Tract 10, Hamilton County, Ohio  \
# 13                                  5781.0
# 14                                  5752.0
# 15                                     6.0
# 16                                    23.0
#
#     Census Tract 16, Hamilton County, Ohio  \
# 13                                  5931.0
# 14                                  5849.0
# 15                                    81.0
# 16                                     1.0
#
#     Census Tract 17, Hamilton County, Ohio  TOTAL (All Selected Census Tracts)
# 13                                  6353.0                             25630.0
# ...

# %%
CreateNewDf(pdf1950)
# Out:
#                                             Category  \
# 13                                 Total Population:
# 14                                             White
# 15                                             Black
# 16                                             Other
# 14                                 Total Population:
# 15                                             White
# 16                                             Black
# 17                                        Other Race
# 33                                 Total Population:
# 34                                             White
# 35                                             Black
# 36                                   Some Other Race
# 38                                 Total Population:
# 39                                             White
# 40                                             Black
# 41                American Indian, Eskimo, and Aleut
# 42                        Asian and Pacific Islander
# ...

# %%
CreateNewDf(pdf1960)
# Out:
#              Category  Census Tract 9, Hamilton County, Ohio  \
# 13  Total Population:                                 7565.0
# 14              White                                 7474.0
# 15              Black                                   79.0
# 16              Other                                   12.0
#
#     Census Tract 10, Hamilton County, Ohio  \
# 13                                  5781.0
# 14                                  5752.0
# 15                                     6.0
# 16                                    23.0
#
#     Census Tract 16, Hamilton County, Ohio  \
# 13                                  5931.0
# 14                                  5849.0
# 15                                    81.0
# 16                                     1.0
#
#     Census Tract 17, Hamilton County, Ohio  TOTAL (All Selected Census Tracts)
# 13                                  6353.0                             25630.0
# ...

# %%
# iterate over the rows
for i, row in pdf1950.iloc[1:2].iterrows():
    # create a list representing the dataframe row
    White_1950_rows = [row['Census Tract 9, Hamilton County, Ohio'], row['Census Tract 10, Hamilton County, Ohio'],
                       row['Census Tract 16, Hamilton County, Ohio'], row['Census Tract 17, Hamilton County, Ohio'],
                       row['TOTAL (All Selected Census Tracts)']]

# %%
White_1950_rows
